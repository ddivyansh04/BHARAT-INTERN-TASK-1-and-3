# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#lets see the plots of bedrooms

# %%
df['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=df.lat.values, y=df.long.values, size=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()

sns.despine
#this is to check the density acc to latitude and longitude
# Out:
# /Users/divyanshdiwakar/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/divyanshdiwakar/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
#now let's check the price vs size of the houses

# %%
plt.scatter(x=df.price,y=df.sqft_living)
plt.xlabel('PRICES')
plt.ylabel('AREA')
plt.show()

# %%
plt.scatter(df.bedrooms,df.price)
plt.title("Bedroom and Price ")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
#like that we can visualize all of them but these are enough

# %%
X=df.drop(['date','id','price'],axis=1)

# %%
X.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
Y=df.price

# %%
#let's split the data

# %%
from sklearn.model_selection import train_test_split

x_train , x_test , y_train , y_test = train_test_split(X,Y, test_size = 0.10,random_state =2)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
conv_dates = [1 if values == 2014 else 0 for values in df.date ]
df['date'] = conv_dates

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test,y_test)
# Out:
# 0.7320342760357311

# %%
#as score is not good so let's try other method

# %%
from sklearn import ensemble

clf = ensemble.GradientBoostingRegressor(n_estimators=400, 
                                         max_depth=5, 
                                         min_samples_split=2,
                                         learning_rate=0.1, 
                                         loss='squared_error')  # Use 'squared_error' instead of 'ls'

# Now you can proceed to train your model

# %%
clf.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=400)

# %%
clf.score(x_test,y_test)
# Out:
# 0.9201252436743027

# %%
#as by this ensemble method we are getting enough score

predictions_reg = reg.predict(x_test)
predictions_clf = clf.predict(x_test)

# %%
import matplotlib.pyplot as plt

# Assuming y_test, x_test, reg, and clf are defined

# Scatter plot for predictions from reg (Linear Regressor)
plt.scatter(y_test, reg.predict(x_test), color='green', label='Linear Regressor Predictions')

# Scatter plot for predictions from clf (GradientBoostingRegressor)
plt.scatter(y_test, clf.predict(x_test), color='orange', label='GradientBoostingRegressor Predictions')

plt.title('Comparison of Predictions from Linear Regressor and GradientBoostingRegressor')
plt.xlabel('y_test')
plt.ylabel('Predictions')
plt.legend()
plt.grid(True)
plt.show()
